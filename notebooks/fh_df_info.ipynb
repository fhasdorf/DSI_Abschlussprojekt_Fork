# %%
import pandas as pd

# %%
# Schnellübersicht: Struktur und Inhalt des Hauptdatensatzes
df=pd.read_csv("../data/raw/data.csv")
#df.head(20)
df.describe()
df.info()

# %%
# Spaltennamen als Liste ausgeben
print(df.columns.tolist())

# %%
import pandas as pd

# Parquet-Datei einlesen (lädt nur die Metadaten/Spalten)
df = pd.read_parquet('../data/processed/data.parquet', columns=[])

# Spaltennamen als Liste ausgeben
spalten = list(df.columns)
print(spalten)
# Out:
# []
